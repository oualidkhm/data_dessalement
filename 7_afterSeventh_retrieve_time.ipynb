# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# --- 1. CHARGEMENT ET PRÉPARATION ---
print("Chargement des données...")
df = pd.read_csv('df_minute_aggregated.csv')
dfnew = pd.read_csv('dataset_backwash.csv')
# Out:
# Chargement des données...

# %%
df.shape
# Out:
# (449002, 92)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=449002, step=1)

# %%
dfnew.shape
# Out:
# (449002, 97)

# %%
dfnew.index
# Out:
# RangeIndex(start=0, stop=449002, step=1)

# %%
# df = ton ancien dataset avec la colonne time
# dfnew = ton nouveau dataset avec toutes les colonnes backwash

dfnew["time"] = df["time"].values  # copie la colonne time
dfnew.set_index("time", inplace=True)  # remettre comme index

# %%
dfnew.head()
# Out:
#                      INTAKE LINE PRESSURE OF HMMF FEED PUMPS  \
# time
# 2024-02-13 11:38:00                                  1.49075
# 2024-02-13 11:39:00                                  1.49650
# 2024-02-13 11:40:00                                  1.49525
# 2024-02-13 11:41:00                                  1.49625
# 2024-02-13 11:42:00                                  1.50775
#
#                      FIT_001A_FLOW AT INLET HMMF-A  \
# time
# 2024-02-13 11:38:00                     454.837494
# 2024-02-13 11:39:00                     454.837494
# 2024-02-13 11:40:00                     454.837494
# 2024-02-13 11:41:00                     454.837494
# 2024-02-13 11:42:00                     454.837494
#
#                      FIT_001B_FLOW AT INLET HMMF-B  \
# time
# 2024-02-13 11:38:00                     391.059570
# 2024-02-13 11:39:00                     388.655182
# 2024-02-13 11:40:00                     386.984314
# 2024-02-13 11:41:00                     386.413788
# ...

# %%
dfnew.index.name = "time"
dfnew.to_csv("dataset_backwash_withtime.csv", index=True)


# quand charger: df = pd.read_csv("dataset_backwash_final.csv", index_col="time", parse_dates=True)
